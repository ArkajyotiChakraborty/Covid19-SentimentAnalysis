# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('COVID.csv')
df
# Out:
#                     Tweet Id  ... User Account Creation Date
# 0      "1233417783175778304"  ...       30 Jun 2013 00:27:50
# 1      "1233417742520332290"  ...       12 Feb 2010 21:43:17
# 2      "1233417741027225602"  ...       09 Dec 2008 01:54:21
# 3      "1233417699264356357"  ...       25 Mar 2007 19:14:46
# 4      "1233417674274807808"  ...       06 Dec 2008 08:56:45
# ...                      ...  ...                        ...
# 60155  "1204309839004012544"  ...       23 May 2012 14:30:12
# 60156  "1204212528810729479"  ...       06 Jan 2016 01:12:42
# 60157  "1204206609708331009"  ...       15 Nov 2013 03:20:11
# 60158  "1201998948950577152"  ...       26 Apr 2018 15:07:50
# 60159  "1200977067266990080"  ...       27 Mar 2014 16:58:36
#
# [60160 rows x 22 columns]

# %%
#dividing this dataset into 3 parts in which we will perform our modeling..
# df1: covidsenti A
# df2 :  covidsenti B
# df3: covidsenti C

df1 = df.iloc[0:20000,:]
df1
# Out:
#                     Tweet Id  ... User Account Creation Date
# 0      "1233417783175778304"  ...       30 Jun 2013 00:27:50
# 1      "1233417742520332290"  ...       12 Feb 2010 21:43:17
# 2      "1233417741027225602"  ...       09 Dec 2008 01:54:21
# 3      "1233417699264356357"  ...       25 Mar 2007 19:14:46
# 4      "1233417674274807808"  ...       06 Dec 2008 08:56:45
# ...                      ...  ...                        ...
# 19995  "1223393601754845184"  ...       12 Nov 2012 16:08:09
# 19996  "1223393600932909056"  ...       09 Apr 2013 14:01:51
# 19997  "1223393600496635905"  ...       23 Mar 2009 10:48:50
# 19998  "1223393598735101957"  ...       12 Mar 2009 10:05:26
# 19999  "1223393598705557504"  ...       23 Jul 2009 20:12:52
#
# [20000 rows x 22 columns]

# %%
df2 = df.iloc[20000:40000,:]
df2
# Out:
#                     Tweet Id  ... User Account Creation Date
# 20000  "1223393598403727360"  ...       15 Jan 2019 15:53:17
# 20001  "1223393598235926528"  ...       18 Apr 2017 12:40:25
# 20002  "1223393597585854464"  ...       05 May 2019 21:34:23
# 20003  "1223393597120106496"  ...       21 Jun 2010 21:30:21
# 20004  "1223393595882987521"  ...       25 Jan 2017 18:26:22
# ...                      ...  ...                        ...
# 39995  "1223376209360441347"  ...       28 Aug 2019 11:06:08
# 39996  "1223376208508809216"  ...       26 Apr 2017 02:23:14
# 39997  "1223376207888179200"  ...       13 Feb 2011 15:06:14
# 39998  "1223376206436933633"  ...       20 Dec 2012 21:55:20
# 39999  "1223376206013325317"  ...       23 Jul 2010 20:12:28
#
# [20000 rows x 22 columns]

# %%
df3 = df.iloc[40000:60160,:]
df3
# Out:
#                     Tweet Id  ... User Account Creation Date
# 40000  "1223376205275172866"  ...       14 Mar 2016 04:09:37
# 40001  "1223376204994088962"  ...       13 Mar 2016 18:50:01
# 40002  "1223376204973137932"  ...       30 Aug 2016 18:59:59
# 40003  "1223376204956303362"  ...       28 Mar 2019 20:50:36
# 40004  "1223376204906082309"  ...       31 Oct 2010 09:25:06
# ...                      ...  ...                        ...
# 60155  "1204309839004012544"  ...       23 May 2012 14:30:12
# 60156  "1204212528810729479"  ...       06 Jan 2016 01:12:42
# 60157  "1204206609708331009"  ...       15 Nov 2013 03:20:11
# 60158  "1201998948950577152"  ...       26 Apr 2018 15:07:50
# 60159  "1200977067266990080"  ...       27 Mar 2014 16:58:36
#
# [20160 rows x 22 columns]

# %%
df.describe()
# Out:
#        Retweets Received  Likes Received  ...  User Followers  User Following
# count       60160.000000     60160.00000  ...    6.016000e+04    6.016000e+04
# mean            3.142886         5.27259  ...    9.274935e+04    2.193178e+03
# std           106.443453        98.29730  ...    8.309707e+05    1.196382e+04
# min             0.000000         0.00000  ...    0.000000e+00    0.000000e+00
# 25%             0.000000         0.00000  ...    1.450000e+02    2.040000e+02
# 50%             0.000000         0.00000  ...    5.500000e+02    5.620000e+02
# 75%             0.000000         0.00000  ...    2.449500e+03    1.692000e+03
# max         23832.000000     17526.00000  ...    2.127516e+07    1.182667e+06
#
# [8 rows x 6 columns]

# %%
# the column names

for col in df.columns:
  print(col)
# Out:
# Tweet Id
# Tweet URL
# Tweet Posted Time (UTC)
# Tweet Content
# Tweet Type
# Client
# Retweets Received
# Likes Received
# Tweet Location
# Lat
# Long
# Tweet Language
# User Id
# Name
# Screen Name
# User Bio
# Verified or Non-Verified
# Profile URL
# Protected or Non-protected
# User Followers
# User Following
# User Account Creation Date

# %%
df.drop(['Tweet Id',
'Tweet URL',
'Tweet Posted Time (UTC)',
'Tweet Type',
'Client',
'Retweets Received',
'Likes Received',
'Tweet Location',
'Lat',
'Long',
'Tweet Language',
'User Id',
'Name',
'Screen Name',
'User Bio',
'Verified or Non-Verified',
'Profile URL',
'Protected or Non-protected',
'User Followers',
'User Following',
'User Account Creation Date'], axis = 1, inplace = True)

# %%
df.head()
# Out:
#                                        Tweet Content
# 0  Also the entire Swiss Football League is on ho...
# 1  World Health Org Official: Trump’s press confe...
# 2  I mean, Liberals are cheer-leading this #Coron...
# 3  Under repeated questioning, Pompeo refuses to ...
# 4  #coronavirus comments now from @larry_kudlow h...

# %%
df1.drop(['Tweet Id',
'Tweet URL',
'Tweet Posted Time (UTC)',
'Tweet Type',
'Client',
'Retweets Received',
'Likes Received',
'Tweet Location',
'Lat',
'Long',
'Tweet Language',
'User Id',
'Name',
'Screen Name',
'User Bio',
'Verified or Non-Verified',
'Profile URL',
'Protected or Non-protected',
'User Followers',
'User Following',
'User Account Creation Date'], axis = 1, inplace = True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4174: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
df1.head()
# Out:
#                                        Tweet Content
# 0  Also the entire Swiss Football League is on ho...
# 1  World Health Org Official: Trump’s press confe...
# 2  I mean, Liberals are cheer-leading this #Coron...
# 3  Under repeated questioning, Pompeo refuses to ...
# 4  #coronavirus comments now from @larry_kudlow h...

# %%
df2.drop(['Tweet Id',
'Tweet URL',
'Tweet Posted Time (UTC)',
'Tweet Type',
'Client',
'Retweets Received',
'Likes Received',
'Tweet Location',
'Lat',
'Long',
'Tweet Language',
'User Id',
'Name',
'Screen Name',
'User Bio',
'Verified or Non-Verified',
'Profile URL',
'Protected or Non-protected',
'User Followers',
'User Following',
'User Account Creation Date'], axis = 1, inplace = True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4174: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
df2.head()
# Out:
#                                            Tweet Content
# 20000  RT @PressSec: President @realDonaldTrump is ta...
# 20001  Tedros Adhanom, Director General de la OMS: "D...
# 20002  RT @La_manina__: Salvini dice che la Lega da g...
# 20003  RT @AlanAdameMX: ✈️ Tiene razón @m_ebrard, los...
# 20004  RT @TombStoneWyatt: This is in the infected di...

# %%
df3.drop(['Tweet Id',
'Tweet URL',
'Tweet Posted Time (UTC)',
'Tweet Type',
'Client',
'Retweets Received',
'Likes Received',
'Tweet Location',
'Lat',
'Long',
'Tweet Language',
'User Id',
'Name',
'Screen Name',
'User Bio',
'Verified or Non-Verified',
'Profile URL',
'Protected or Non-protected',
'User Followers',
'User Following',
'User Account Creation Date'], axis = 1, inplace = True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4174: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
df3.head()
# Out:
#                                            Tweet Content
# 40000  RT @MinSaludGuate: #MSPAS #MinSaludGt #NotiSal...
# 40001  RT @sanidadgob: El Centro Nacional de Microbio...
# 40002  RT @pietroraffa: Salgo su un treno per Pesaro....
# 40003  RT @PedroMCasals: Emergencia internacional por...
# 40004  RT @sanidadgob: El Centro Nacional de Microbio...

# %%
# now as we have divided the dataset we will be using textblob for analysing the sentiments.

# !pip install textblob
# Out:
# Requirement already satisfied: textblob in /usr/local/lib/python3.7/dist-packages (0.15.3)
# Requirement already satisfied: nltk>=3.1 in /usr/local/lib/python3.7/dist-packages (from textblob) (3.2.5)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from nltk>=3.1->textblob) (1.15.0)

# %%
from textblob import TextBlob

# %% [markdown]
# # Function we are using according to the paper for deciding and grouping polarity.
#
# ![image.png](data:image/png;base64,...)

# %%
def ratio(x):
  if x>0.4:
    return 1
  elif x<-0.4:
    return -1
  else:
    return 0;

# %% [markdown]
# # Working On the DF using textblob

# %%
polarity = lambda x: TextBlob(x).sentiment.polarity
subjectivity = lambda x: TextBlob(x).sentiment.subjectivity
df['polarity'] = df['Tweet Content'].apply(polarity)
df['subjectivity'] = df['Tweet Content'].apply(subjectivity)

# %%
df['class'] = df['polarity'].apply(ratio)
df
# Out:
#                                            Tweet Content  ...  class
# 0      Also the entire Swiss Football League is on ho...  ...      0
# 1      World Health Org Official: Trump’s press confe...  ...      0
# 2      I mean, Liberals are cheer-leading this #Coron...  ...      0
# 3      Under repeated questioning, Pompeo refuses to ...  ...      0
# 4      #coronavirus comments now from @larry_kudlow h...  ...      0
# ...                                                  ...  ...    ...
# 60155  El #coronavirus entérico felino es un virus in...  ...      0
# 60156  RT @timhquotes: It's my party, you're invited!...  ...      0
# 60157  It's my party, you're invited!\n\nPS, this is ...  ...      0
# 60158  Amy’s a survivor! #bariclab #pnnl #movingon #c...  ...      0
# 60159  A review of asymptomatic and sub-clinical Midd...  ...      0
#
# [60160 rows x 4 columns]

# %%
df['class'].unique()
# Out:
# array([ 0,  1, -1])

# %%
# number of tweets in each section
df['class'].value_counts()
# Out:
#  0    57212
#  1     2134
# -1      814
# Name: class, dtype: int64

# %%
df['class'].value_counts().plot(kind = 'bar')
plt.show()

# %% [markdown]
# # Working on DF1

# %%
polarity = lambda x: TextBlob(x).sentiment.polarity
subjectivity = lambda x: TextBlob(x).sentiment.subjectivity
df1['polarity'] = df1['Tweet Content'].apply(polarity)
df1['subjectivity'] = df1['Tweet Content'].apply(subjectivity)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
# applying textblob
df1['class'] = df1['polarity'].apply(ratio)
df1
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                            Tweet Content  ...  class
# 0      Also the entire Swiss Football League is on ho...  ...      0
# 1      World Health Org Official: Trump’s press confe...  ...      0
# 2      I mean, Liberals are cheer-leading this #Coron...  ...      0
# 3      Under repeated questioning, Pompeo refuses to ...  ...      0
# 4      #coronavirus comments now from @larry_kudlow h...  ...      0
# ...                                                  ...  ...    ...
# 19995  RT @Arslan_Crickter: She is a volunteer lady d...  ...      0
# 19996  RT @BraveTheWorld: India just announced that t...  ...      0
# 19997  RT @TuurDemeester: #coronavirus: New HK study ...  ...      0
# 19998  RT @PDChina: 20 patients were discharged from ...  ...      0
# 19999  RT @rinachandran: Forced to stay indoors, more...  ...      0
#
# [20000 rows x 4 columns]

# %%
df1['class'].value_counts()
# Out:
#  0    18650
#  1     1019
# -1      331
# Name: class, dtype: int64

# %%
df1['class'].value_counts().plot(kind = 'bar')
plt.show()

# %% [markdown]
# # Working on the DF2

# %%
polarity = lambda x: TextBlob(x).sentiment.polarity
subjectivity = lambda x: TextBlob(x).sentiment.subjectivity
df2['polarity'] = df2['Tweet Content'].apply(polarity)
df2['subjectivity'] = df2['Tweet Content'].apply(subjectivity)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
df2['class'] = df2['polarity'].apply(ratio)
df2
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                                            Tweet Content  ...  class
# 20000  RT @PressSec: President @realDonaldTrump is ta...  ...      0
# 20001  Tedros Adhanom, Director General de la OMS: "D...  ...      0
# 20002  RT @La_manina__: Salvini dice che la Lega da g...  ...      0
# 20003  RT @AlanAdameMX: ✈️ Tiene razón @m_ebrard, los...  ...      0
# 20004  RT @TombStoneWyatt: This is in the infected di...  ...      0
# ...                                                  ...  ...    ...
# 39995  RT @WalhallaMann: Estados Unidos prohibió el i...  ...      0
# 39996  @theJagmeetSingh How #China treats the livesto...  ...      0
# 39997  #ÚltimaHora \nPrimer caso de #coronavirus de W...  ...      0
# 39998  RT @pietroraffa: Salgo su un treno per Pesaro....  ...      0
# 39999  RT @SaludPublicaEs: Forma parte de un grupo de...  ...      0
#
# [20000 rows x 4 columns]

# %%
df2['class'].value_counts()
# Out:
#  0    19219
#  1      528
# -1      253
# Name: class, dtype: int64

# %%
df['class'].value_counts().plot(kind = 'bar')
plt.show()

# %% [markdown]
# # working on DF3

# %%
polarity = lambda x: TextBlob(x).sentiment.polarity
subjectivity = lambda x: TextBlob(x).sentiment.subjectivity
df3['polarity'] = df3['Tweet Content'].apply(polarity)
df3['subjectivity'] = df3['Tweet Content'].apply(subjectivity)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
df3['class'] = df3['polarity'].apply(ratio)
df3
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                                            Tweet Content  ...  class
# 40000  RT @MinSaludGuate: #MSPAS #MinSaludGt #NotiSal...  ...      0
# 40001  RT @sanidadgob: El Centro Nacional de Microbio...  ...      0
# 40002  RT @pietroraffa: Salgo su un treno per Pesaro....  ...      0
# 40003  RT @PedroMCasals: Emergencia internacional por...  ...      0
# 40004  RT @sanidadgob: El Centro Nacional de Microbio...  ...      0
# ...                                                  ...  ...    ...
# 60155  El #coronavirus entérico felino es un virus in...  ...      0
# 60156  RT @timhquotes: It's my party, you're invited!...  ...      0
# 60157  It's my party, you're invited!\n\nPS, this is ...  ...      0
# 60158  Amy’s a survivor! #bariclab #pnnl #movingon #c...  ...      0
# 60159  A review of asymptomatic and sub-clinical Midd...  ...      0
#
# [20160 rows x 4 columns]

# %%
df3['class'].value_counts()
# Out:
#  0    19343
#  1      587
# -1      230
# Name: class, dtype: int64

# %%
df3['class'].value_counts().plot(kind = 'bar')
plt.show()

# %% [markdown]
# # Tweet Processing

# %% [markdown]
# 1. Removing @users

# %%
import re

# %%
def remove_pattern(input_txt, pattern):
    r = re.findall(pattern, input_txt)
    for i in r:
        input_txt = re.sub(i,'',input_txt)
    return input_txt

# %%
df['Processed_Tweet'] = np.vectorize(remove_pattern)(df['Tweet Content'], '@[\w]*')

# %%
df.head()
# Out:
#                                        Tweet Content  ...                                    Processed_Tweet
# 0  Also the entire Swiss Football League is on ho...  ...  Also the entire Swiss Football League is on ho...
# 1  World Health Org Official: Trump’s press confe...  ...  World Health Org Official: Trump’s press confe...
# 2  I mean, Liberals are cheer-leading this #Coron...  ...  I mean, Liberals are cheer-leading this #Coron...
# 3  Under repeated questioning, Pompeo refuses to ...  ...  Under repeated questioning, Pompeo refuses to ...
# 4  #coronavirus comments now from @larry_kudlow h...  ...  #coronavirus comments now from  here. https://...
#
# [5 rows x 5 columns]

# %% [markdown]
# 2. Removing the HTTP's and URL's from tweets

# %%
df['Processed_Tweet'] = df['Tweet Content'].apply(lambda x: re.split('https:\/\/.*', str(x))[0])

# %%
df.head(2)
# Out:
#                                        Tweet Content  ...                                    Processed_Tweet
# 0  Also the entire Swiss Football League is on ho...  ...  Also the entire Swiss Football League is on ho...
# 1  World Health Org Official: Trump’s press confe...  ...  World Health Org Official: Trump’s press confe...
#
# [2 rows x 5 columns]

# %% [markdown]
# 3. Removing the special characters, numbers

# %%
df['Processed_Tweet'] = df['Tweet Content'].str.replace('[^a-zA-Z#]+',' ')

# %%
df.head(2)
# Out:
#                                        Tweet Content  ...                                    Processed_Tweet
# 0  Also the entire Swiss Football League is on ho...  ...  Also the entire Swiss Football League is on ho...
# 1  World Health Org Official: Trump’s press confe...  ...  World Health Org Official Trump s press confer...
#
# [2 rows x 5 columns]

# %% [markdown]
# 4. Removing the Short words.

# %%
df['Processed_Tweet'] = df['Tweet Content'].apply(lambda x: ' '.join([w for w in x.split() if len(w) > 2]))

# %%
df.head()
# Out:
#                                        Tweet Content  ...                                    Processed_Tweet
# 0  Also the entire Swiss Football League is on ho...  ...  Also the entire Swiss Football League hold. Po...
# 1  World Health Org Official: Trump’s press confe...  ...  World Health Org Official: Trump’s press confe...
# 2  I mean, Liberals are cheer-leading this #Coron...  ...  mean, Liberals are cheer-leading this #Coronav...
# 3  Under repeated questioning, Pompeo refuses to ...  ...  Under repeated questioning, Pompeo refuses say...
# 4  #coronavirus comments now from @larry_kudlow h...  ...  #coronavirus comments now from @larry_kudlow h...
#
# [5 rows x 5 columns]

# %%
from wordcloud import WordCloud

# %%
all_words = ' '.join([text for text in df['Processed_Tweet']])

# %%
wordcloud = WordCloud(width=800, height=500, random_state=21, max_font_size=110).generate(all_words)

plt.figure(figsize=(10, 7))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.show()

# %%
normal_words = ' '.join([text for text in df['Processed_Tweet'][df['class'] == 0]])

wordcloud = WordCloud(width=800, height=500, random_state=21, max_font_size=110).generate(normal_words)
plt.figure(figsize=(10, 7))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.show()

# %%
# understanding the hashtags
hashtags = [] 
def hashtag_extract(x):
    #hashtags = []
    for i in x:
        ht = re.findall(r'#(\w+)', i)
        hashtags.append(ht)
    return hashtags

# %%
HT_Positive = hashtag_extract(df['Processed_Tweet'][df['class']==1])

# %%
HT_Negetive = hashtag_extract(df['Processed_Tweet'][df['class']==-1])

# %%
HT_Neutral = hashtag_extract(df['Processed_Tweet'][df['class']==0])

# %%
Tweet_Word = []

# %%
Tweet_Word = sum(HT_Positive,[])

# %%
Tweet_Word = sum(HT_Negetive,[])

# %%
Tweet_Word = sum(HT_Neutral,[])

# %%
Tweet_Word = pd.DataFrame(Tweet_Word)

# %%
Tweet_Word.describe()
# Out:
#                   0
# count        134934
# unique        10854
# top     coronavirus
# freq          42714

# %%
Tweet_Word
# Out:
#                     0
# 0           DailyDose
# 1               Delhi
# 2         Coronavirus
# 3         coronavirus
# 4           COVID2019
# ...               ...
# 134929           bsl3
# 134930        science
# 134931       grownups
# 134932  professorlife
# 134933    Coronavirus
#
# [134934 rows x 1 columns]

# %%
new_df = df[['Processed_Tweet','class']]

# %%
new_df
# Out:
#                                          Processed_Tweet  class
# 0      Also the entire Swiss Football League hold. Po...      0
# 1      World Health Org Official: Trump’s press confe...      0
# 2      mean, Liberals are cheer-leading this #Coronav...      0
# 3      Under repeated questioning, Pompeo refuses say...      0
# 4      #coronavirus comments now from @larry_kudlow h...      0
# ...                                                  ...    ...
# 60155  #coronavirus entérico felino virus intestinal ...      0
# 60156  @timhquotes: It's party, you're invited! PS, t...      0
# 60157  It's party, you're invited! PS, this life phil...      0
# 60158  Amy’s survivor! #bariclab #pnnl #movingon #cor...      0
# 60159  review asymptomatic and sub-clinical Middle Ea...      0
#
# [60160 rows x 2 columns]

# %%
x = new_df['Processed_Tweet']
y = new_df['class']

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer(max_features = 8000 )
# tokenize and build vocab

vectorizer.fit(x)
# summarize

print(len(vectorizer.vocabulary_))
print(vectorizer.idf_.shape)
# Out:
# 8000
# (8000,)

# %%
x_tfidf = vectorizer.transform(x).toarray()
print(x_tfidf.shape)
# Out:
# (60160, 8000)

# %%
from sklearn.model_selection import train_test_split as tts

# %%
x_train,x_test,y_train,y_test = tts(x_tfidf,y,test_size = 0.05)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (57152, 8000)
# (3008, 8000)
# (57152,)
# (3008,)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
from sklearn.svm import LinearSVC
from sklearn.svm import SVC
from sklearn.linear_model import SGDClassifier
from sklearn.metrics import confusion_matrix, accuracy_score

# %%
svm_model = LinearSVC(class_weight='balanced',multi_class='crammer_singer',max_iter = -1).fit(x_train, y_train)
svm_model_predict = svm_model.predict(x_test)
svm_report = classification_report(y_test, svm_model_predict )
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)

# %%
print(svm_report)
# Out:
#               precision    recall  f1-score   support
#
#           -1       0.74      0.82      0.78        49
#            0       0.99      0.98      0.99      2841
#            1       0.69      0.86      0.77       118
#
#     accuracy                           0.97      3008
#    macro avg       0.81      0.88      0.84      3008
# weighted avg       0.98      0.97      0.97      3008
